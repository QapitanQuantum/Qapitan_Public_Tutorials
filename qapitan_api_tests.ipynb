# %%
import requests
import json

# %%
# Get your private endpoint and credentials from our team - info@qapitan.com
QAPITAN_PUBLIC_API = "https://a52um7l0kf.execute-api.us-east-1.amazonaws.com/prd/"
PAYLOAD_USER = {"username": "sergio@qapitan.com", "password": "qapitan"}

# %%
# This problem only admits one parameter. The size of the bitstring to randomly generate
PAYLOAD_QRNG = {
    "data": {
        "size": 20
    }
}

# %%
response = requests.post(QAPITAN_PUBLIC_API + '/login', json=PAYLOAD_USER)
response_json = response.json()

# %%
print(response_json)
# Out:
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2VtYWlsIjoic2VyZ2lvQHFhcGl0YW4uY29tIiwiZXhwIjoxNjQ0NjkzMjU2fQ.UzFR-iloyFPUoIQW09v6YjKr9DjnAV4MYf-XwjDz_e0'}

# %%
access_token = response_json['access_token']
header = {'Authorization': 'Bearer ' + access_token}

# %%
print(header)
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2VtYWlsIjoic2VyZ2lvQHFhcGl0YW4uY29tIiwiZXhwIjoxNjQ0NjkzMjU2fQ.UzFR-iloyFPUoIQW09v6YjKr9DjnAV4MYf-XwjDz_e0'}

# %%
response_jobs = requests.get(QAPITAN_PUBLIC_API + "/results", headers=header)
response_json_jobs = response_jobs.json()

# %%
print(response_json_jobs)
# Out:
# {'results': {'OIGH9ES49YCK': {'status': 'ERROR', 'started_at': '02/10/2022, 13:21:04', 'end_at': '02/10/2022, 13:22:47', 'executions': {'qapitan-solver-expectedshortfall': {'started_at': '', 'end_at': '02/10/2022, 13:22:35', 'status': 'ERROR', 'data': {'loans': [[0.15, 0.1, 100000], [0.25, 0.05, 200000], [0.2, 0.07, 300000], [0.02, 0.01, 400000]], 'alpha': 0.03}, 'arguments': '', 'result': "'No IBM Quantum Experience credentials found.'"}}}, 'AKBKTYUVT6EM': {'status': 'ERROR', 'started_at': '02/10/2022, 14:24:04', 'end_at': '02/10/2022, 14:25:44', 'executions': {'qapitan-solver-expectedshortfall': {'started_at': '', 'end_at': '02/10/2022, 14:25:52', 'status': 'ERROR', 'data': {'loans': [[0.15, 0.1, 100000], [0.25, 0.05, 200000], [0.2, 0.07, 300000], [0.02, 0.01, 400000]], 'alpha': 0.03}, 'arguments': '', 'result': "'No IBM Quantum Experience credentials found.'"}}}, 'PE0SJ5GACF9X': {'status': 'ERROR', 'started_at': '02/10/2022, 15:06:38', 'end_at': '02/10/2022, 15:08:39', 'executions': {'Solver_Qapitan_QUBO_Framework-Maxcut-annealing_sim-dwave-local': {'started_at': '', 'end_at': '02/10/2022, 15:08:26', 'status': 'ERROR', 'data': {'edges': [[0, 1], [0, 2], [1, 3], [2, 3], [1, 4], [3, 4]]}, 'arguments': '', 'result': 'Object of type int8 is not JSON serializable'}}}, 'A0KLMKRUAVG2': {'status': 'ERROR', 'started_at': '02/10/2022, 18:24:21', 'end_at': '02/10/2022, 18:37:38', 'executions': {'qapitan-solver-expectedshortfall': {'started_at': '', 'end_at': '02/10/2022, 18:37:26', 'status': 'ERROR', 'data': {'loans': [[0.15, 0.1, 100000], [0.25, 0.05, 200000], [0.2, 0.07, 300000], [0.02, 0.01, 400000]], 'alpha': 0.03}, 'arguments': '', 'result': 'Object of type int64 is not JSON serializable'}}}, 'Z0JMH6FGFEBI': {'status': 'ERROR', 'started_at': '02/10/2022, 18:40:38', 'end_at': '02/10/2022, 18:42:22', 'executions': {'Solver_Qapitan_QUBO_Framework-Maxcut-annealing_sim-dwave-local': {'started_at': '', 'end_at': '02/10/2022, 18:42:12', 'status': 'ERROR', 'data': {'edges': [[0, 1], [0, 2], [1, 3], [2, 3], [1, 4], [3, 4]]}, 'arguments': '', 'result': 'Object of type int8 is not JSON serializable'}}}, '0O85YX26GQJ3': {'status': 'ERROR', 'started_at': '02/10/2022, 18:54:04', 'end_at': '02/10/2022, 19:04:50', 'executions': {'qapitan-solver-expectedshortfall': {'started_at': '', 'end_at': '02/10/2022, 19:04:38', 'status': 'ERROR', 'data': {'loans': [[0.15, 0.1, 100000], [0.25, 0.05, 200000], [0.2, 0.07, 300000], [0.02, 0.01, 400000]], 'alpha': 0.03}, 'arguments': '', 'result': 'Object of type int64 is not JSON serializable'}}}, 'QUMHQEXJ0YH3': {'status': 'FINISHED', 'started_at': '02/10/2022, 21:33:23', 'end_at': '02/10/2022, 21:35:08', 'executions': {'Solver_Qapitan_QUBO_Framework-Maxcut-annealing_sim-dwave-local': {'started_at': '', 'end_at': '02/10/2022, 21:34:56', 'status': 'SUCCESS', 'data': {'edges': [[0, 1], [0, 2], [1, 3], [2, 3], [1, 4], [3, 4]]}, 'arguments': '', 'result': [[1, 0, 0, 1, 0], [-5, -0.22727272727272727]]}}}, 'E3L4LR91M0AV': {'status': 'FINISHED', 'started_at': '02/10/2022, 21:44:28', 'end_at': '02/10/2022, 21:46:09', 'executions': {'Solver_Qapitan_QUBO_Framework-Maxcut-annealing_sim-dwave-local': {'started_at': '', 'end_at': '02/10/2022, 21:45:57', 'status': 'SUCCESS', 'data': {'edges': [[0, 1], [0, 2], [1, 3], [2, 3], [2, 4], [3, 4]]}, 'arguments': '', 'result': [[0, 1, 1, 0, 0], [-5, -0.22727272727272727]]}}}, 'SJ8VFPMQRBZ4': {'status': 'ERROR', 'started_at': '02/10/2022, 21:44:52', 'end_at': '02/10/2022, 21:46:21', 'executions': {'Solver_Qapitan_QUBO_Framework-Tsp-annealing_sim-dwave-local': {'started_at': '', 'end_at': '02/10/2022, 21:46:11', 'status': 'ERROR', 'data': {'number_nodes': 9, 'weight_matrix': [[-1.0, 0.0928905987022528, 0.04694935086215485, 0.8195861037747975, 0.20610242983222293, 0.14984150359756676, 0.16221866632606863, 0.11061985338530292, 0.6393368646950607], [0.0928905987022528, -1.0, 0.07876878065960502, 0.871856272558227, 0.1301633997356444, 0.22320362091321194, 0.09438196495830918, 0.030433923 ...

# %%
job_name = "SCWC8TTV2YH3"
response_job = requests.get(QAPITAN_PUBLIC_API + "/job/" + job_name, headers=header)
response_json_job = response_job.json()

# %%
print(response_json_job)
# Out:
# {'job': {'SCWC8TTV2YH3': {'status': 'FINISHED', 'started_at': '02/07/2022, 12:51:28', 'end_at': '02/07/2022, 12:52:55', 'executions': {'qapitan-solver-qrng': {'started_at': '', 'end_at': '02/07/2022, 12:52:45', 'status': 'SUCCESS', 'data': {'size': 20}, 'arguments': '', 'result': '01111001100101000000'}}}}}

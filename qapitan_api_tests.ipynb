# %%
import requests
import json

# %%
# Get your private endpoint and credentials from our team - info@qapitan.com
QAPITAN_PUBLIC_API = "https://a52um7l0kf.execute-api.us-east-1.amazonaws.com/prd/"
PAYLOAD_USER = {"username": "sergio@qapitan.com", "password": "qapitan"}

# %%
# This problem only admits one parameter. The size of the bitstring to randomly generate
PAYLOAD_QRNG = {
    "data": {
        "size": 20
    }
}

# %%
response = requests.post(QAPITAN_PUBLIC_API + '/login', json=PAYLOAD_USER)
response_json = response.json()

# %%
print(response_json)
# Out:
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2VtYWlsIjoic2VyZ2lvQHFhcGl0YW4uY29tIiwiZXhwIjoxNjQ0MjQ4NjYzfQ.6KyzHNkr5TDftRVvOn_T-lfWyP1zpaOx5kjZ1A9c930'}

# %%
access_token = response_json['access_token']
header = {'Authorization': 'Bearer ' + access_token}

# %%
print(header)
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2VtYWlsIjoic2VyZ2lvQHFhcGl0YW4uY29tIiwiZXhwIjoxNjQ0MjQ4NjYzfQ.6KyzHNkr5TDftRVvOn_T-lfWyP1zpaOx5kjZ1A9c930'}

# %%
response_jobs = requests.get(QAPITAN_PUBLIC_API + "/results", headers=header)
response_json_jobs = response_jobs.json()

# %%
print(response_json_jobs)
# Out:
# {'job': {'SCWC8TTV2YH3': {'status': 'FINISHED', 'started_at': '02/07/2022, 12:51:28', 'end_at': '02/07/2022, 12:52:55', 'executions': {'qapitan-solver-qrng': {'started_at': '', 'end_at': '02/07/2022, 12:52:45', 'status': 'SUCCESS', 'data': {'size': 20}, 'arguments': '', 'result': ''}}}, 'OA0301BIVF5D': {'status': 'FINISHED', 'started_at': '02/07/2022, 12:51:19', 'end_at': '02/07/2022, 12:52:48', 'executions': {'qapitan-solver-qrng': {'started_at': '', 'end_at': '02/07/2022, 12:52:37', 'status': 'SUCCESS', 'data': {'size': 20}, 'arguments': '', 'result': ''}}}, 'J6YHFI0WF9AC': {'status': 'FINISHED', 'started_at': '02/07/2022, 12:50:59', 'end_at': '02/07/2022, 12:52:26', 'executions': {'qapitan-solver-qrng': {'started_at': '', 'end_at': '02/07/2022, 12:52:16', 'status': 'SUCCESS', 'data': {'size': 20}, 'arguments': '', 'result': ''}}}, 'IPT832VR1F8M': {'status': 'FINISHED', 'started_at': '02/07/2022, 12:49:33', 'end_at': '02/07/2022, 12:51:18', 'executions': {'Solver_Qapitan_QUBO_Frame
# ...

# %%
job_name = "SCWC8TTV2YH3"
response_job = requests.get(QAPITAN_PUBLIC_API + "/job/" + job_name, headers=header)
response_json_job = response_job.json()

# %%
print(response_json_job)
# Out:
# {'job': {'SCWC8TTV2YH3': {'status': 'FINISHED', 'started_at': '02/07/2022, 12:51:28', 'end_at': '02/07/2022, 12:52:55', 'executions': {'qapitan-solver-qrng': {'started_at': '', 'end_at': '02/07/2022, 12:52:45', 'status': 'SUCCESS', 'data': {'size': 20}, 'arguments': '', 'result': ''}}}}}
